# %%
import pandas as pd
import numpy as np
import seaborn as sns

# %%
df=pd.read_excel("C:\\Users\\rahul\\Downloads\\cardekho_data_36f227e7-994e-4ac0-98d7-b4684ce4de44.xlsx")
df
# Out:
#     Car_Name  Year  Selling_Price  Present_Price  Kms_Driven Fuel_Type  \
# 0       ritz  2014           3.35           5.59       27000    Petrol
# 1        sx4  2013           4.75           9.54       43000    Diesel
# 2       ciaz  2017           7.25           9.85        6900    Petrol
# 3    wagon r  2011           2.85           4.15        5200    Petrol
# 4      swift  2014           4.60           6.87       42450    Diesel
# ..       ...   ...            ...            ...         ...       ...
# 296     city  2016           9.50          11.60       33988    Diesel
# 297     brio  2015           4.00           5.90       60000    Petrol
# 298     city  2009           3.35          11.00       87934    Petrol
# 299     city  2017          11.50          12.50        9000    Diesel
# 300     brio  2016           5.30           5.90        5464    Petrol
#
#     Seller_Type Transmission  Owner
# 0        Dealer       Manual      0
# 1        Dealer       Manual      0
# ...

# %%
df['Owner'].value_counts()
# Out:
# Owner
# 0    290
# 1     10
# 3      1
# Name: count, dtype: int64

# %%
df.columns
# Out:
# Index(['Car_Name', 'Year', 'Selling_Price', 'Present_Price', 'Kms_Driven',
#        'Fuel_Type', 'Seller_Type', 'Transmission', 'Owner'],
#       dtype='object')

# %%
from sklearn.preprocessing import LabelEncoder
encoder = LabelEncoder()
df['Fuel_Type']=encoder.fit_transform(df.Fuel_Type)

# %%
df
# Out:
#     Car_Name  Year  Selling_Price  Present_Price  Kms_Driven  Fuel_Type  \
# 0       ritz  2014           3.35           5.59       27000          2
# 1        sx4  2013           4.75           9.54       43000          1
# 2       ciaz  2017           7.25           9.85        6900          2
# 3    wagon r  2011           2.85           4.15        5200          2
# 4      swift  2014           4.60           6.87       42450          1
# ..       ...   ...            ...            ...         ...        ...
# 296     city  2016           9.50          11.60       33988          1
# 297     brio  2015           4.00           5.90       60000          2
# 298     city  2009           3.35          11.00       87934          2
# 299     city  2017          11.50          12.50        9000          1
# 300     brio  2016           5.30           5.90        5464          2
#
#     Seller_Type Transmission  Owner
# 0        Dealer       Manual      0
# ...

# %%
df2=df.drop_duplicates()

# %%
df2
# Out:
#     Car_Name  Year  Selling_Price  Present_Price  Kms_Driven  Fuel_Type  \
# 0       ritz  2014           3.35           5.59       27000          2
# 1        sx4  2013           4.75           9.54       43000          1
# 2       ciaz  2017           7.25           9.85        6900          2
# 3    wagon r  2011           2.85           4.15        5200          2
# 4      swift  2014           4.60           6.87       42450          1
# ..       ...   ...            ...            ...         ...        ...
# 296     city  2016           9.50          11.60       33988          1
# 297     brio  2015           4.00           5.90       60000          2
# 298     city  2009           3.35          11.00       87934          2
# 299     city  2017          11.50          12.50        9000          1
# 300     brio  2016           5.30           5.90        5464          2
#
#     Seller_Type Transmission  Owner
# 0        Dealer       Manual      0
# ...

# %%
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 299 entries, 0 to 300
# Data columns (total 9 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Car_Name       299 non-null    object
#  1   Year           299 non-null    int64
#  2   Selling_Price  299 non-null    float64
#  3   Present_Price  299 non-null    float64
#  4   Kms_Driven     299 non-null    int64
#  5   Fuel_Type      299 non-null    int32
#  6   Seller_Type    299 non-null    object
#  7   Transmission   299 non-null    object
#  8   Owner          299 non-null    int64
# dtypes: float64(2), int32(1), int64(3), object(3)
# memory usage: 22.2+ KB

# %%
#inme se int columns bharn nikalunga me 

df2=df2.select_dtypes(['int','float'])
df2
# Out:
#      Year  Selling_Price  Present_Price  Kms_Driven  Fuel_Type  Owner
# 0    2014           3.35           5.59       27000          2      0
# 1    2013           4.75           9.54       43000          1      0
# 2    2017           7.25           9.85        6900          2      0
# 3    2011           2.85           4.15        5200          2      0
# 4    2014           4.60           6.87       42450          1      0
# ..    ...            ...            ...         ...        ...    ...
# 296  2016           9.50          11.60       33988          1      0
# 297  2015           4.00           5.90       60000          2      0
# 298  2009           3.35          11.00       87934          2      0
# 299  2017          11.50          12.50        9000          1      0
# 300  2016           5.30           5.90        5464          2      0
#
# [299 rows x 6 columns]

# %%
#mujhe selling price predict karna hai

# %%
df2.corr()
# Out:
#                    Year  Selling_Price  Present_Price  Kms_Driven  Fuel_Type  \
# Year           1.000000       0.234369      -0.053563   -0.525714  -0.046210
# Selling_Price  0.234369       1.000000       0.876378    0.028566  -0.500292
# Present_Price -0.053563       0.876378       1.000000    0.205253  -0.431809
# Kms_Driven    -0.525714       0.028566       0.205253    1.000000  -0.167287
# Fuel_Type     -0.046210      -0.500292      -0.431809   -0.167287   1.000000
# Owner         -0.181639      -0.087880       0.009947    0.089367   0.054174
#
#                   Owner
# Year          -0.181639
# Selling_Price -0.087880
# Present_Price  0.009947
# Kms_Driven     0.089367
# Fuel_Type      0.054174
# Owner          1.000000

# %%
df2.isnull().sum()

#esme null value chek karunga agar ha to clean karo
# Out:
# Year             0
# Selling_Price    0
# Present_Price    0
# Kms_Driven       0
# Fuel_Type        0
# Owner            0
# dtype: int64

# %%
x = df2[['Year','Present_Price','Kms_Driven','Fuel_Type']]
y = df2['Selling_Price']

# %%
from sklearn import linear_model

# %%
# x aur Y data ko tran kara diya mane 

regr = linear_model.LinearRegression()
regr.fit(x,y)
# Out:
# LinearRegression()

# %%
#x = df2[['Year','Present_Price','Kms_Driven','Fuel_Type']]


predicted = regr.predict([[2015,9.85,5000,2]])
predicted
# Out:
# C:\ProgramData\anaconda3\Lib\site-packages\sklearn\base.py:464: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([6.13480895])

# %%
print(predicted)
# Out:
# [6.13480895]

# %%
# yeha mene sabhi ki Prediction kar di 

# then ham eski Accuray check karenge 

predicted2 = regr.predict(x)
predicted2
# Out:
# array([ 3.52503668e+00,  6.49399544e+00,  7.01285140e+00,  1.57806841e+00,
#         5.63425136e+00,  9.00845203e+00,  5.23585226e+00,  6.96223942e+00,
#         7.59293287e+00,  7.07894851e+00,  3.97754653e+00,  7.75874973e+00,
#         6.13989270e+00,  5.00750314e+00,  1.90689343e+00,  8.43291052e+00,
#         7.99533606e+00,  6.77814048e+00,  2.86579306e+00,  3.61692007e+00,
#         5.00749116e+00,  3.28988405e+00,  2.41319550e+00,  2.38955251e+00,
#         1.93094465e+00,  3.10969976e+00,  5.33493972e+00,  8.84622814e-01,
#         7.78208462e+00,  4.27899363e+00,  1.74907436e+00,  5.95060953e+00,
#         7.12926474e+00,  6.20578453e+00,  6.24571867e+00,  4.66976581e+00,
#        -3.35106522e+00,  3.58211343e+00, -3.13171492e-01,  5.53413766e+00,
#         2.66172878e+00,  1.51041518e+00,  6.20275100e+00,  1.13317420e+00,
#         6.72326590e+00,  2.59432351e+00, -8.68082295e-01,  5.00800873e+00,
# ...

# %% [markdown]
# # yeh mane iski Acuuracy chek kari

# %%
from sklearn.metrics import r2_score
print(r2_score(y,predicted2))
# Out:
# 0.8609695922504532
