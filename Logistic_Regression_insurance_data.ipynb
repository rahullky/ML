# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %% [raw]
# Sigmoid Function   ka oupput Binary Format me deta hai

# %%
df=pd.read_excel(r"C:\Users\rahul\Downloads\ML_Data\ML_Data_sheet.xlsx","Logistic_Binary")
df

# Linear Regression me Discreate Data set hota hai 
# Logistic Regression me Catogorical Data Set hota hai 
# WE will catgoriacal data Convert to  Binary
# Out:
#     Age Insurance
# 0    22        No
# 1    25        No
# 2    47       Yes
# 3    52        No
# 4    46       Yes
# 5    56       Yes
# 6    55        No
# 7    60       Yes
# 8    62       Yes
# 9    61       Yes
# 10   18        No
# 11   28        No
# 12   27        No
# 13   29        No
# 14   49       Yes

# %%
plt.scatter(x='Age',y='Insurance',data=df,color='red',marker='+')

# %%
# We will Our data set Split 
from sklearn.model_selection import train_test_split

# %% [markdown]
# # step 1:--->train_test_split(df[['age']],df['bought_insurance'],test_size=t_size=0.2)

# %%
# step 2:--->
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(df[['Age']],df['Insurance'],test_size=0.1)

# %%
len(x_train)
# Out:
# 13

# %%
len(x_test)
# Out:
# 2

# %%
from sklearn.linear_model import LogisticRegression

model=LogisticRegression()

# %%
model.fit(x_train,y_train)
# Out:
# LogisticRegression()

# %%
x_test
# Out:
#    Age
# 6   55
# 1   25

# %%
model.predict(x_test)
# Out:
# array(['Yes', 'No'], dtype=object)

# %%
model.predict([[5]])
# Out:
# C:\Users\rahul\AppData\Roaming\Python\Python311\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but LogisticRegression was fitted with feature names
#   warnings.warn(
# array(['No'], dtype=object)

# %%
x_test
# Out:
#    Age
# 6   55
# 1   25

# %%
model.predict_proba(x_test)
# Out:
# array([[0.07658931, 0.92341069],
#        [0.97692531, 0.02307469]])

# %%
# OUr Logistic Regression Will Tell Us Probality Percentafge %
